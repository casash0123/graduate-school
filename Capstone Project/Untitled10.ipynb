# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q "/content/drive/My Drive/SRP.v1i.yolov8.zip" -d /content/dataset
# Out:
# replace /content/dataset/README.dataset.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace /content/dataset/README.roboflow.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 51.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 31.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # 또는 yolov8s.pt
model.train(data='/content/dataset/data.yaml', epochs=30, imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 73.2MB/s]
# Ultralytics 8.3.144 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
model.val()
# Out:
# Ultralytics 8.3.144 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 833.9±111.1 MB/s, size: 32.3 KB)
# val: Scanning /content/dataset/valid/labels.cache... 7 images, 0 backgrounds, 0 corrupt: 100%|██████████| 7/7 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.27s/it]
#                    all          7          7      0.287       0.92      0.746      0.601
#                  paper          4          4      0.336      0.759      0.845       0.67
#                   rock          1          1      0.319          1      0.995      0.895
#               scissors          2          2      0.205          1      0.398      0.237
# Speed: 2.4ms preprocess, 298.6ms inference, 0.0ms loss, 12.9ms postprocess per image
# Results saved to runs/detect/train3
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ...

# %%
from ultralytics import YOLO

model = YOLO('runs/detect/train/weights/best.pt')
model.predict(source='/content/dataset/test/images', save=True)
# Out:
# image 1/4 /content/dataset/test/images/KakaoTalk_20250525_230749034_04_jpg.rf.77c4776657f2aa721338607d85e400c2.jpg: 640x640 (no detections), 400.0ms
# image 2/4 /content/dataset/test/images/suggested-9hHRpQEazDYzoiD4yatU_jpg.rf.7f47c061fbff2acfe391468a7bbd3147.jpg: 640x640 (no detections), 355.5ms
# image 3/4 /content/dataset/test/images/suggested-FSyhnwdGNHhWfHoOLGnd_jpg.rf.d5dfab3326fb92e06678faa6af8436ca.jpg: 640x640 (no detections), 367.4ms
# image 4/4 /content/dataset/test/images/suggested-vIl09zaAQjPVjtmESWM4_jpg.rf.3c3263dc9b3efd0739258d7b15d90cf1.jpg: 640x640 (no detections), 356.2ms
# Speed: 5.4ms preprocess, 369.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'paper', 1: 'rock', 2: 'scissors'}
#  obb: None
#  orig_img: array([[[223, 223, 223],
# ...

# %%
from ultralytics import YOLO

model = YOLO('runs/detect/train/weights/best.pt')
model.predict(source='/content/dataset/train/images', save=True)
# Out:
# image 1/25 /content/dataset/train/images/KakaoTalk_20250525_230749034_02_jpg.rf.0f98975f8abbec9e90495c761ca99d7a.jpg: 640x640 (no detections), 339.5ms
# image 2/25 /content/dataset/train/images/KakaoTalk_20250525_230749034_05_jpg.rf.480c0a45fb4609dcf97e2c1e2c2eed49.jpg: 640x640 (no detections), 350.5ms
# image 3/25 /content/dataset/train/images/KakaoTalk_20250525_230749034_07_jpg.rf.838a50274ce4263f4cdd4c3b9df7322f.jpg: 640x640 (no detections), 365.2ms
# image 4/25 /content/dataset/train/images/KakaoTalk_20250525_230749034_09_jpg.rf.502419c34d40f6a6e2d6a277b49ae442.jpg: 640x640 (no detections), 343.7ms
# image 5/25 /content/dataset/train/images/KakaoTalk_20250525_231623344_01_jpg.rf.ebafc0e2f8fb7487e7be30bb3935ea8f.jpg: 640x640 (no detections), 355.7ms
# image 6/25 /content/dataset/train/images/KakaoTalk_20250525_231623344_02_jpg.rf.1005a62b279e83b8423f1dab1429f449.jpg: 640x640 (no detections), 368.0ms
# ...
